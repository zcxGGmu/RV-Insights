# %%
import os
from zhipu_llm import ZhipuAILLM
from dotenv import find_dotenv, load_dotenv

_ = load_dotenv(find_dotenv())
api_key = os.environ["ZHIPUAI_API_KEY"]

llm = ZhipuAILLM(model = "chatglm-pro",
                 zhipuai_api_key = api_key,
                 temperature = 0.1)
llm("你是谁？")
